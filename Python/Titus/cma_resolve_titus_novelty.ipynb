# %%
import matplotlib.pyplot as plt
import pygame
import numpy as np
import random
import copy
import cma
import pickle
import functools
import operator
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
##### CONSTANTES
k = 30
directions = [6,8,10,12,30,40,60]
k_dir =len(directions)
N_in = k + 2 + 2 
N1 =10
N2 = 10
N_out = k + k_dir
f = 0.3
rb = 3
rt = 20
m = 1
g = 9.81
best_distance = 300
nb_dep = 200

angles = [i * 2*np.pi/k for i in range(k)]
print(angles)

ratio_distance = 0.5
ratio_angle = 100


num_elites = 3
nbre_mouvements = 50
nb_gen = 20
nb_pop = 100
mutation_rate = 2/(nbre_mouvements*2)
v_max = 10
# Out:
# [0.0, 0.20943951023931953, 0.41887902047863906, 0.6283185307179586, 0.8377580409572781, 1.0471975511965976, 1.2566370614359172, 1.4660765716752369, 1.6755160819145563, 1.8849555921538759, 2.0943951023931953, 2.3038346126325147, 2.5132741228718345, 2.7227136331111543, 2.9321531433504737, 3.1415926535897927, 3.3510321638291125, 3.5604716740684323, 3.7699111843077517, 3.979350694547071, 4.1887902047863905, 4.39822971502571, 4.607669225265029, 4.817108735504349, 5.026548245743669, 5.235987755982989, 5.445427266222309, 5.654866776461628, 5.8643062867009474, 6.073745796940267]

# %%
###### FONCTIONS UTILES

def produitvectoriel(vect1,vect2):
    return (vect1[0]*vect2[1] - vect1[1]*vect2[0])

def produitscalaire(vect1,vect2):
    return(vect1[0]*vect2[0] + vect1[1]*vect2[1])

def draw_circle(matrice,i,j,r, colour):
    for x in range(len(matrice)):
        for y in range(len(matrice[x])):
            if abs((x-i)**2 + (y-j)**2) <=r**2:
                matrice[x,y] = colour

def get_line(start, end):
    x1, y1 = start
    x2, y2 = end
    dx = x2 - x1
    dy = y2 - y1
    is_steep = abs(dy) > abs(dx)
    if is_steep:
        x1, y1 = y1, x1
        x2, y2 = y2, x2
    swapped = False
    if x1 > x2:
        x1, x2 = x2, x1
        y1, y2 = y2, y1
        swapped = True
    dx = x2 - x1
    dy = y2 - y1
    error = int(dx / 0.5)
    ystep = 1 if y1 < y2 else -1
    y = y1
    points = []
    for x in range(x1, x2 + 1):
        coord = (y, x) if is_steep else (x, y)
        points.append(coord)
        error -= abs(dy)
        if error < 0:
            y += ystep
            error += dx
    if swapped:
        points.reverse()
    return points


def draw_segment(matrice, start,end):
    points = get_line(start, end)
    shape = np.shape(matrice)
    for i in points:
        if i[0]<shape[0] and i[1] < shape[1]:
            matrice[i[0],i[1]] = 0.7

# %%
##### CLASSE JOUEUR
class Joueur:  
    def __init__(self, array_trou,array_balle,obstacles, nbre_mouvements):
        self.is_best = False
        self.fitness = 0
        self.liste_mouvements = []
        self.liste_emplacements = [array_balle]
        self.nn = Simple_nn(N_in,N1,N_out)
            
    def evaluate_fitness(self):
        a = best_distance
        distance = np.sqrt((self.partie.trou.position[0] - self.partie.balle.position[0])**2 + (self.partie.trou.position[1] - self.partie.balle.position[1])**2 ) 
        if self.partie.reached_goal:
            #print("victoire")
            self.fitness = 100
        elif (not self.partie.is_dead): 
            #print(distance)
            self.fitness = 10000000/(distance)**4
        else:
            self.fitness = -5000/self.partie.nb_coups
        return float(self.fitness)
            
        
    def faire_partie(self,array_balle):
        self.partie = Partie(array_balle,array_trou,obstacles)
        for i in range(nb_dep):
            if self.partie.reached_goal:
                for i in range(nb_dep - i):
                    self.liste_emplacements.append(self.liste_emplacements[-1])
                self.evaluate_fitness()
                return
            
            if self.partie.is_dead:
                for i in range(nb_dep - i):
                    self.liste_emplacements.append(self.liste_emplacements[-1])
                self.evaluate_fitness()
                return
            
            else:
                a = self.partie.distances()
                b = np.array([self.partie.balle.position[0],self.partie.balle.position[1],self.partie.trou.position[0],self.partie.trou.position[1]]) 
                c = np.concatenate((a, b)).flatten()
                y = self.nn.compute(c)
                self.liste_mouvements.append(y)
                a = self.partie.deplacement(y)
                self.liste_emplacements.append(a)
        return

# %%
###### CLASSE POPULATION

class Population:
    def __init__(self, solutions, arraytrou, obstacles, arrayballe = None):
        #if arrayballe == None:
         #   arrayballe = [np.ceil(random.random()*599+100),np.ceil(random.random()*599+100)]
        #self.array_balle = arrayballe
        self.liste_joueur = []
        self.solutions = solutions
        self.nb_not_dead = 0
        for i in range(len(solutions)):
            if arrayballe == None:
                array_balle = [np.ceil(random.random()*599+100),np.ceil(random.random()*599+100)]
                joueur = Joueur(arraytrou,array_balle,obstacles, nbre_mouvements)
                joueur.nn.transform(solutions[i])
                joueur.faire_partie(array_balle)
                joueur.evaluate_fitness()
                self.liste_joueur.append(joueur)
            else:
                joueur = Joueur(arraytrou,arrayballe,obstacles, nbre_mouvements)
                joueur.nn.transform(solutions[i])
                joueur.faire_partie(arrayballe)
                joueur.evaluate_fitness()
                self.liste_joueur.append(joueur)
                
            if (not joueur.partie.is_dead):
                self.nb_not_dead += 1
        
    def total_transform(self, arraytrou, obstacles, arrayballe = [np.ceil(random.random()*599+100),np.ceil(random.random()*599+100)]):
        self.liste_joueur = []
        self.nb_not_dead = 0
        for i in range(len(self.solutions)):
            joueur = Joueur(array_trou,arrayballe,obstacles, nbre_mouvements)
            joueur.nn.transform(self.solutions[i])
            joueur.faire_partie(arrayballe)
            joueur.evaluate_fitness()
            self.liste_joueur.append(joueur)
            if (not joueur.partie.is_dead):
                self.nb_not_dead += 1
        
        
    def to_array(self):
        imax = 0 
        for i in range(len(self.liste_joueur)):
            if self.fitness_function(i) > self.fitness_function(imax):
                imax = i
        return self.liste_joueur[imax].nn.to_array()
    
    def to_array_golbal(self):
        l = []
        for i in range(len(self.liste_joueur)):
            l.append(self.liste_joueur[i].nn.to_array())
        return l    
    
    def fitness_function(self,i):
        fitness = -1
        joueur = self.liste_joueur[i]
        for i in range(len(self.liste_joueur)):
            if (not self.liste_joueur[i].partie.is_dead):
                distance = np.sqrt((joueur.partie.balle.position[0] - self.liste_joueur[i].partie.balle.position[0])**2 + \
                                   (joueur.partie.balle.position[1] - self.liste_joueur[i].partie.balle.position[1])**2)
                fitness += (distance /self.nb_not_dead)**2
        fitness = fitness * joueur.fitness
        return fitness
        
    def print_partie(self,arraytrou, arrayballe, obstacles, nbre_mouvements):
        pygame.init()
        win = pygame.display.set_mode((800,800))
        pygame.display.set_caption("Le mini-golf de l'enfer")
        x_trou = int(arraytrou[0])
        y_trou = int(arraytrou[1])
        win.fill((0,128,0))
        for i in obstacles:
            pygame.draw.line(win, (0,0,0), i.depart, i.arrivee,10)

        run = True
        couleur = self.generer_couleur()
        for i in range(nbre_mouvements): 
            pygame.time.delay(1)
            for event in pygame.event.get():
                if event.type == pygame.QUIT:
                    run = False
            pygame.draw.circle(win, (0,0,0), (x_trou,y_trou), rt)
            for obs in obstacles:
                pygame.draw.line(win, (0,0,0), obs.depart, obs.arrivee,10)
            ind_coul = 0
            for j in self.liste_joueur:
                pygame.draw.circle(win, couleur[ind_coul], (int(j.liste_emplacements[i][0]),int(j.liste_emplacements[i][1])), rb)
                pygame.display.update()
                ind_coul += 1
            win.fill((0,128,0))
        print("fin")
        pygame.display.flip()
        pygame.quit()
        
    def generer_couleur(self):
        couleur = []
        for i in range(nb_pop):
            couleur.append((random.randint(0,250),random.randint(0,250),random.randint(0,250)))
        return couleur

# %%
###### CLASSE NEURAL NETWORK
class Simple_nn:
    def __init__(self, N_in, N1,N_out):
        self.fitness = 0
        self.l1 = np.random.random((N_in,N1))
        self.l2 = np.random.random((N1,N2))
        self.out = np.random.random((N2,N_out))
    
    def compute(self,inputs):
        x = np.dot(self.l1,np.reshape(inputs,(N_in,1)))
        x = np.dot(self.l2, x)
        x = np.dot(self.out,x)
        x = x/(N_in*N1)
        x = x.flatten()
        x = np.abs(x)
        v = x[0,0]
        v = directions[ np.argmax(x[0,:k_dir]) ]
        angle = angles[ np.argmax(x[0,k_dir:]) ]
        return ([v, angle])
    
    def to_array(self):
            array = []
            for i in self.l1:
                array.append(np.asarray(i))
            for i in self.l2:
                array.append(np.asarray(i))
            for i in self.out:
                array.append(np.asarray(i))
                a = functools.reduce(operator.iconcat, array, [])
            return functools.reduce(operator.iconcat, a, [])
        
    def transform(self, genes):
        layers = [self.l1.flatten(),self.l2.flatten(),self.out.flatten()]
        L = 0
        j = 0
        for i in range(len(genes)):
            if j >= len(layers[L]):
                L += 1
                j = 0
            layers[L][j] = genes[i]
            j += 1
        self.l1 = np.reshape(np.asmatrix(layers[0]),(N1,N_in))
        self.l2 = np.reshape(np.asmatrix(layers[1]),(N2,N1))
        self.out = np.reshape(np.asmatrix(layers[2]),(N_out,N2))

# %%
#### CLASSE SEGMENT

class Segment:
    def __init__(self,array1,array2):
        self.depart = array1
        self.arrivee = array2
        
    def cross(self , segment):
        ab = [self.arrivee[0] - self.depart[0] , self.arrivee[1] - self.depart[1]]
        apbp = [segment.arrivee[0] - segment.depart[0] , segment.arrivee[1] - segment.depart[1]]
        abp = [segment.arrivee[0] - self.depart[0], segment.arrivee[1] - self.depart[1]]
        aap = [segment.depart[0] - self.depart[0], segment.depart[1] - self.depart[1] ]
        apb = [self.arrivee[0] - segment.depart[0] , self.arrivee[1] - segment.depart[1]]
        apa = [self.depart[0] - segment.depart[0] , self.depart[1] - segment.depart[1]]
        
        c1 = produitvectoriel(ab,apbp) != 0
        c2 = (produitvectoriel(ab,abp) * produitvectoriel(ab,aap))<=0
        c3 = (produitvectoriel(apbp,apb) * produitvectoriel(apbp,apa))<=0
        return(c1 and c2 and c3)

# %%
##### CLASSE TROU

class Trou:
    def __init__(self, array):
        self.position = array.copy()

# %%
##### CLASSE BALLE

class Balle:
    def __init__(self, array):
        self.position = array.copy()

# %%
##### CLASSE PARTIE

class Partie:
    def __init__(self, arrayballe,arraytrou, obstacles):
        self.balle = Balle(arrayballe)
        self.trou = Trou(arraytrou)
        self.obstacles = obstacles
        self.is_dead = False
        self.nb_coups = 1
        self.reached_goal = False 
        
    def is_won(self):
        distance = np.sqrt((self.trou.position[0] - self.balle.position[0])**2 + (self.trou.position[1] - self.balle.position[1])**2 )
        if distance < rt :
            self.reached_goal = True
    
    def is_possible_move(self,segment_dep):
        liste_obstacles_cross = []
        for i in self.obstacles: # Pour tous les obstacles
            if i.cross(segment_dep): # Si un segment_dep et i se croisent alors le move n'est pas possible
                    liste_obstacles_cross.append(i)
        if len(liste_obstacles_cross) > 0 :
            liste_distances = []
            liste_inter = []
            for i in liste_obstacles_cross:
                if (segment_dep.depart[0] - segment_dep.arrivee[0] == 0):
                    a_i = (i.depart[1] - i.arrivee[1]) / (i.depart[0] - i.arrivee[0])
                    b_i = i.depart[1] - a_i *i.depart[0]
                    x_inter = segment_dep.depart[0]
                    y_inter = a_i * x_inter + b_i
                    liste_inter.append([x_inter , y_inter])
                    
                    
                elif (i.depart[0] - i.arrivee[0] == 0):
                    a_segment_dep = (segment_dep.depart[1] - segment_dep.arrivee[1]) / (segment_dep.depart[0] - segment_dep.arrivee[0])
                    b_segment_dep = segment_dep.depart[1] - a_segment_dep * segment_dep.depart[0]
                    x_inter = i.depart[0]
                    y_inter = a_segment_dep * x_inter + b_segment_dep
                    liste_inter.append([x_inter , y_inter])
                
                else :
                    a_segment_dep = (segment_dep.depart[1] - segment_dep.arrivee[1]) / (segment_dep.depart[0] - segment_dep.arrivee[0])
                    b_segment_dep = segment_dep.depart[1] - a_segment_dep * segment_dep.depart[0]
                    a_i = (i.depart[1] - i.arrivee[1]) / (i.depart[0] - i.arrivee[0])
                    b_i = i.depart[1] - a_i *i.depart[0]
                    x_inter = (b_i - b_segment_dep) / (a_segment_dep - a_i)
                    y_inter = a_i * x_inter + b_i
                    liste_inter.append([x_inter , y_inter])
                
                liste_distances.append(np.sqrt( (x_inter - self.balle.position[0])**2 + (y_inter - self.balle.position[1])**2))
            self.balle.position[0] = liste_inter[liste_distances.index(min(liste_distances))][0]
            self.balle.position[1] = liste_inter[liste_distances.index(min(liste_distances))][1]
                
            return False
        return True
    
    def remplir_matrice(self):
        self.matrice = np.zeros((800,800))
        draw_circle(self.matrice,int(self.trou.position[0]),int(self.trou.position[1]),rt,0.2)
        for i in obstacles:
            draw_segment(self.matrice, i.depart,i.arrivee)
        
    def deplacement(self,vitesse_initiale): # La vitesse sera de la forme [ ||v|| , theta)]
        distance =vitesse_initiale[0]
        #print("distance : "+str(distance))
        segment_dep = Segment([self.balle.position[0],self.balle.position[1]],[self.balle.position[0] + np.cos(vitesse_initiale[1]) * distance,self.balle.position[1] + np.sin(vitesse_initiale[1]) * distance] )
        self.is_won()
        
        if self.reached_goal:
            return (self.balle.position[0],self.balle.position[1])
        if self.is_possible_move(segment_dep):
            self.nb_coups +=1
            self.balle.position[0] += np.cos(vitesse_initiale[1]) * distance
            self.balle.position[1] += np.sin(vitesse_initiale[1]) * distance
        else :
            self.is_dead = True
        return (self.balle.position[0],self.balle.position[1])
    
    def closest_distance(self,angle):
        x = self.balle.position[0]
        y = self.balle.position[1]
        xf = x + 8000*np.cos(angle)
        yf = y + 8000*np.sin(angle)
        segment_dep = Segment([x,y],[xf,yf])
        liste_obstacles_cross = []
        liste_distances = []
        liste_inter = []
        
        for i in self.obstacles: # Pour tous les obstacles
            if i.cross(segment_dep): # Si un segment_dep et i se croisent alors le move n'est pas possible
                    liste_obstacles_cross.append(i)
        for i in liste_obstacles_cross:
            if (segment_dep.depart[0] - segment_dep.arrivee[0] == 0):
                a_i = (i.depart[1] - i.arrivee[1]) / (i.depart[0] - i.arrivee[0])
                b_i = i.depart[1] - a_i *i.depart[0]
                x_inter = segment_dep.depart[0]
                y_inter = a_i * x_inter + b_i
                liste_inter.append([x_inter , y_inter])


            elif (i.depart[0] - i.arrivee[0] == 0):
                a_segment_dep = (segment_dep.depart[1] - segment_dep.arrivee[1]) / (segment_dep.depart[0] - segment_dep.arrivee[0])
                b_segment_dep = segment_dep.depart[1] - a_segment_dep * segment_dep.depart[0]
                x_inter = i.depart[0]
                y_inter = a_segment_dep * x_inter + b_segment_dep
                liste_inter.append([x_inter , y_inter])

            else :
                a_segment_dep = (segment_dep.depart[1] - segment_dep.arrivee[1]) / (segment_dep.depart[0] - segment_dep.arrivee[0])
                b_segment_dep = segment_dep.depart[1] - a_segment_dep * segment_dep.depart[0]
                a_i = (i.depart[1] - i.arrivee[1]) / (i.depart[0] - i.arrivee[0])
                b_i = i.depart[1] - a_i *i.depart[0]
                x_inter = (b_i - b_segment_dep) / (a_segment_dep - a_i)
                y_inter = a_i * x_inter + b_i
                liste_inter.append([x_inter , y_inter])

            liste_distances.append(np.sqrt( (x_inter - self.balle.position[0])**2 + (y_inter - self.balle.position[1])**2))
        inter_x = liste_inter[liste_distances.index(min(liste_distances))][0]
        inter_y = liste_inter[liste_distances.index(min(liste_distances))][1]

        distance = np.sqrt((x-inter_x)**2 + (y-inter_y)**2)
        return distance
    
    
    
    def distances(self):
        distances = []
        for i in range(k):
            distances.append(self.closest_distance(angles[i]))
        return distances

# %%
#DEFINITION DE LA PARTIE
obstacles = []
# On ajoute les murs
obstacles.append(Segment([100,100],[100,700]))
obstacles.append(Segment([100,100],[700,100]))
obstacles.append(Segment([100,700],[700,700]))
obstacles.append(Segment([700,100],[700,700]))
# On ajoute les obstacles
#obstacles.append(Segment([600,500],[600,700]))
#obstacles.append(Segment([400,200],[400,100]))
obstacles.append(Segment([700,350],[250,350]))
#obstacles.append(Segment([400,350],[400,550]))


array_balle = [600,60]
array_trou = [650,150]
partie = Partie(array_balle,array_trou, obstacles)

partie.remplir_matrice()
plt.figure(figsize = (800,800))
im1 = plt.matshow(partie.matrice, interpolation = 'bilinear')
plt.colorbar(im1)
plt.plot([])
plt.show()
a = partie.distances()
print(a)
# Out:
# [50.0, 51.11702974325146, 54.7318139253023, 61.8033988749895, 67.28163648031882, 57.73502691896258, 52.57311121191338, 50.27541397817581, 50.27541397817581, 52.57311121191334, 57.735026918962525, 67.28163648031868, 85.06508083520401, 122.92966677871179, 240.48671723720636, 550.0, 562.287327175766, 602.0499531783257, 679.8373876248843, 403.68981888191297, 346.41016151377556, 315.4386672714802, 301.65248386905495, 301.6524838690549, 161.80339887498948, 99.99999999999994, 74.72382749323043, 61.8033988749895, 54.73181392530235, 51.11702974325146]

# %%
#population = pickle.load( open( "./data/gen_nov180.pkl", "rb" ) )
x0 = np.random.randn(N_in*N1+N2*N1+ N2*N_out)
#x0 = population.to_array()
es = pickle.load(open( "./data/last_cma_nov.pkl", "rb" ) )
#es = cma.CMAEvolutionStrategy(x0,0.2)
i = 1
while True:
    solutions = es.ask()
    population = Population(solutions, array_trou ,obstacles,array_balle)
    es.tell(solutions, [-population.fitness_function(i) for i in range(len(solutions))])
    nb_victoires = sum([i.partie.reached_goal for i in population.liste_joueur])
    print("nb de victoires : "+str(nb_victoires))
    if nb_victoires > 0:
        print("terminé !")
        with open("./data/gen_nov"+str(i)+".pkl", 'wb') as pickle_file:
            pickle.dump(population, pickle_file)
        #population.total_transform(array_trou, obstacles, array_balle)
        #print(" En commencant du début, meilleur fit = "+str(-max([i.fitness for i in population.liste_joueur])))
        with open("./data/last_cma_nov.pkl", 'wb') as pickle_file:
            pickle.dump(es, pickle_file)  
        es.stop()
    print("nb de morts : "+str(sum([i.partie.is_dead for i in population.liste_joueur])))
    if i%10 == 0: 
        with open("./data/gen_nov"+str(i)+".pkl", 'wb') as pickle_file:
            pickle.dump(population, pickle_file)
        #population.total_transform(array_trou, obstacles, array_balle)
        #print(" En commencant du début, meilleur fit = "+str(-max([i.fitness for i in population.liste_joueur])))
        with open("./data/last_cma_nov.pkl", 'wb') as pickle_file:
            pickle.dump(es, pickle_file)  
    es.logger.add()
    es.disp()
    i += 1
    print(" calculating generation : "+str(i))
# Out:
# nb de victoires : 0
# nb de morts : 7
#  calculating generation : 2
# nb de victoires : 0
# nb de morts : 8
#   802  19248 -2.369579899187570e+00 1.3e+00 1.49e-01  1e-01  1e-01 102:51.7
#  calculating generation : 3
# nb de victoires : 0
# nb de morts : 13
#  calculating generation : 4
# nb de victoires : 0
# nb de morts : 7
#  calculating generation : 5
# nb de victoires : 0
# nb de morts : 6
#  calculating generation : 6
# nb de victoires : 0
# nb de morts : 6
#  calculating generation : 7
# nb de victoires : 0
# nb de morts : 3
#  calculating generation : 8
# nb de victoires : 0
# nb de morts : 1
#  calculating generation : 9
# nb de victoires : 0
# nb de morts : 6
#  calculating generation : 10
# nb de victoires : 0
# nb de morts : 7
#  calculating generation : 11
# nb de victoires : 0
# nb de morts : 8
#  calculating generation : 12
# nb de victoires : 0
# nb de morts : 5
#  calculating generation : 13
# nb de victoires : 0
# nb de morts : 7
#   813  19512 -5.479227737217694e+00 1.3e+00 1.49e-01  1e-01  1e-01 104:53.9
#  calculating generation : 14
# nb de victoires : 0
# nb de morts : 8
#  calculating generation : 15
# nb de victoires : 0
# nb de morts : 9
#  calculating generation : 16
# nb de victoires : 0
# nb de morts : 4
#  calculating generation : 17
# nb de victoires : 0
# nb de morts : 9
#  calculating generation : 18
# nb de victoires : 0
# nb de morts : 9
#  calculating generation : 19
# nb de victoires : 0
# nb de morts : 7
#  calculating generation : 20
# nb de victoires : 0
# nb de morts : 8
#  calculating generation : 21
# nb de victoires : 0
# nb de morts : 2
#   821  19704 -1.671692901199722e+00 1.3e+00 1.49e-01  1e-01  1e-01 106:48.6
#  calculating generation : 22
# nb de victoires : 0
# nb de morts : 4
#  calculating generation : 23
# nb de victoires : 0
# nb de morts : 8
#  calculating generation : 24
# nb de victoires : 0
# nb de morts : 3
#  calculating generation : 25
# nb de victoires : 0
# nb de morts : 8
#  calculating generation : 26
# nb de victoires : 0
# nb de morts : 6
#  calculating generation : 27
# nb de victoires : 0
# nb de morts : 7
#  calculating generation : 28
# nb de victoires : 0
# nb de morts : 5
#  calculating generation : 29
# nb de victoires : 0
# nb de morts : 6
#  calculating generation : 30
# nb de victoires : 0
# nb de morts : 2
#  calculating generation : 31
# nb de victoires : 0
# nb de morts : 3
#   831  19944 -1.376782577305701e+00 1.3e+00 1.50e-01  1e-01  2e-01 108:42.0
#  calculating generation : 32
# nb de victoires : 0
# nb de morts : 6
#  calculating generation : 33
# nb de victoires : 0
# nb de morts : 10
#  calculating generation : 34
# nb de victoires : 0
# nb de morts : 7
#  calculating generation : 35
# nb de victoires : 0
# nb de morts : 8
#  calculating generation : 36
# nb de victoires : 0
# nb de morts : 4
#  calculating generation : 37
# nb de victoires : 0
# nb de morts : 11
#  calculating generation : 38
# nb de victoires : 0
# nb de morts : 5
#  calculating generation : 39
# nb de victoires : 0
# nb de morts : 3
#  calculating generation : 40
# nb de victoires : 0
# nb de morts : 6
#   840  20160 -2.216508490191721e+00 1.3e+00 1.50e-01  1e-01  2e-01 110:35.6
#  calculating generation : 41
# nb de victoires : 0
# nb de morts : 5
#  calculating generation : 42
# nb de victoires : 0
# nb de morts : 6
#  calculating generation : 43
# nb de victoires : 0
# nb de morts : 4
#  calculating generation : 44
# nb de victoires : 0
# nb de morts : 8
#  calculating generation : 45
# nb de victoires : 0
# nb de morts : 9
#  calculating generation : 46
# nb de victoires : 0
# nb de morts : 8
#  calculating generation : 47
# nb de victoires : 0
# nb de morts : 11
#   847  20328 -4.772007613938508e+00 1.3e+00 1.50e-01  1e-01  2e-01 112:29.9
#  calculating generation : 48
# nb de victoires : 0
# nb de morts : 8
#  calculating generation : 49
# nb de victoires : 0
# nb de morts : 3
#  calculating generation : 50
# nb de victoires : 0
# nb de morts : 6
#  calculating generation : 51
# nb de victoires : 0
# nb de morts : 8
#  calculating generation : 52
# nb de victoires : 0
# nb de morts : 10
#  calculating generation : 53
# nb de victoires : 0
# nb de morts : 8
#  calculating generation : 54
# nb de victoires : 0
# nb de morts : 6
#  calculating generation : 55
# nb de victoires : 0
# nb de morts : 15
#   855  20520 -8.787512373872753e+00 1.3e+00 1.50e-01  1e-01  2e-01 114:35.3
#  calculating generation : 56
# nb de victoires : 0
# nb de morts : 0
#  calculating generation : 57
# nb de victoires : 0
# nb de morts : 6
#  calculating generation : 58
# nb de victoires : 0
# nb de morts : 6
#  calculating generation : 59
# nb de victoires : 0
# nb de morts : 4
#  calculating generation : 60
# nb de victoires : 0
# nb de morts : 4
#  calculating generation : 61
# nb de victoires : 0
# nb de morts : 2
#  calculating generation : 62
# nb de victoires : 0
# nb de morts : 6
#   862  20688 -2.123143268945700e+00 1.3e+00 1.49e-01  1e-01  2e-01 116:35.9
#  calculating generation : 63
# nb de victoires : 0
# nb de morts : 5
#  calculating generation : 64
# nb de victoires : 0
# nb de morts : 1
#  calculating generation : 65
# nb de victoires : 0
# nb de morts : 2
#  calculating generation : 66
# nb de victoires : 0
# nb de morts : 4
#  calculating generation : 67
# nb de victoires : 0
# nb de morts : 1
#  calculating generation : 68
# nb de victoires : 0
# nb de morts : 2
#  calculating generation : 69
# nb de victoires : 0
# nb de morts : 3
#   869  20856 -1.555339524706312e+00 1.3e+00 1.49e-01  1e-01  1e-01 118:40.5
#  calculating generation : 70
# nb de victoires : 0
# nb de morts : 3
#  calculating generation : 71
# nb de victoires : 0
# nb de morts : 5
#  calculating generation : 72
# nb de victoires : 0
# nb de morts : 7
#  calculating generation : 73
# nb de victoires : 0
# nb de morts : 4
#  calculating generation : 74
# nb de victoires : 0
# nb de morts : 4
#  calculating generation : 75
# nb de victoires : 0
# nb de morts : 4
#  calculating generation : 76
# nb de victoires : 0
# nb de morts : 3
#   876  21024 -3.515773610713120e+00 1.3e+00 1.49e-01  1e-01  1e-01 120:39.1
#  calculating generation : 77
# nb de victoires : 0
# nb de morts : 7
#  calculating generation : 78
# nb de victoires : 0
# nb de morts : 10
#  calculating generation : 79
# nb de victoires : 0
# nb de morts : 6
#  calculating generation : 80
# nb de victoires : 0
# nb de morts : 7
#  calculating generation : 81
# nb de victoires : 0
# nb de morts : 13
#  calculating generation : 82
# nb de victoires : 0
# nb de morts : 10
#  calculating generation : 83
# nb de victoires : 0
# nb de morts : 5
#  calculating generation : 84
# nb de victoires : 0
# nb de morts : 7
#   884  21216 -2.390522806159433e+00 1.3e+00 1.49e-01  1e-01  1e-01 122:46.8
#  calculating generation : 85
# nb de victoires : 0
# nb de morts : 13
#  calculating generation : 86
# nb de victoires : 0
# nb de morts : 9
#  calculating generation : 87
# nb de victoires : 0
# nb de morts : 3
#  calculating generation : 88
# nb de victoires : 0
# nb de morts : 3
#  calculating generation : 89
# nb de victoires : 0
# nb de morts : 4
#  calculating generation : 90
# nb de victoires : 0
# nb de morts : 8
#  calculating generation : 91
# nb de victoires : 0
# nb de morts : 10
#  calculating generation : 92
# nb de victoires : 0
# nb de morts : 16
#   892  21408 -4.293848358218648e+00 1.3e+00 1.49e-01  1e-01  1e-01 124:56.5
#  calculating generation : 93
# nb de victoires : 0
# nb de morts : 5
#  calculating generation : 94
# nb de victoires : 0
# nb de morts : 3
#  calculating generation : 95
# nb de victoires : 0
# nb de morts : 4
#  calculating generation : 96
# nb de victoires : 0
# nb de morts : 7
#  calculating generation : 97
# nb de victoires : 0
# nb de morts : 8
#  calculating generation : 98
# nb de victoires : 0
# nb de morts : 6
#  calculating generation : 99
# nb de victoires : 0
# nb de morts : 11
#  calculating generation : 100
# nb de victoires : 0
# nb de morts : 2
#   900  21600 -2.776775572920655e+00 1.3e+00 1.49e-01  1e-01  1e-01 127:11.5
#  calculating generation : 101
# nb de victoires : 0
# nb de morts : 3
#  calculating generation : 102
# nb de victoires : 0
# nb de morts : 1
#  calculating generation : 103
# nb de victoires : 0
# nb de morts : 5
#  calculating generation : 104
# nb de victoires : 0
# nb de morts : 5
#  calculating generation : 105
# nb de victoires : 0
# nb de morts : 0
#  calculating generation : 106
# nb de victoires : 0
# nb de morts : 5
#  calculating generation : 107
# nb de victoires : 0
# nb de morts : 9
#  calculating generation : 108
# nb de victoires : 0
# nb de morts : 6
#   908  21792 -1.975985793841128e+00 1.3e+00 1.48e-01  1e-01  1e-01 129:27.1
#  calculating generation : 109
# nb de victoires : 0
# nb de morts : 10
#  calculating generation : 110
# nb de victoires : 0
# nb de morts : 10
#  calculating generation : 111
# nb de victoires : 0
# nb de morts : 12
#  calculating generation : 112
# nb de victoires : 0
# nb de morts : 9
#  calculating generation : 113
# nb de victoires : 0
# nb de morts : 10
#  calculating generation : 114
# nb de victoires : 0
# nb de morts : 5
#  calculating generation : 115
# nb de victoires : 0
# nb de morts : 3
#  calculating generation : 116
# nb de victoires : 0
# nb de morts : 4
#   916  21984 -2.403614324908418e+00 1.3e+00 1.48e-01  1e-01  1e-01 131:31.9
#  calculating generation : 117
# nb de victoires : 0
# nb de morts : 4
#  calculating generation : 118
# nb de victoires : 0
# nb de morts : 5
#  calculating generation : 119
# nb de victoires : 0
# nb de morts : 5
#  calculating generation : 120
# nb de victoires : 0
# nb de morts : 7
#  calculating generation : 121
# nb de victoires : 0
# nb de morts : 5
#  calculating generation : 122
# nb de victoires : 0
# nb de morts : 3
#  calculating generation : 123
# nb de victoires : 0
# nb de morts : 13
#  calculating generation : 124
# nb de victoires : 0
# nb de morts : 8
#   924  22176 -2.400585036044139e+00 1.3e+00 1.48e-01  1e-01  1e-01 133:48.2
#  calculating generation : 125
# nb de victoires : 0
# nb de morts : 7
#  calculating generation : 126
# nb de victoires : 0
# nb de morts : 4
#  calculating generation : 127
# nb de victoires : 0
# nb de morts : 4
#  calculating generation : 128
# nb de victoires : 0
# nb de morts : 7
#  calculating generation : 129
# nb de victoires : 0
# nb de morts : 3
#  calculating generation : 130
# nb de victoires : 0
# nb de morts : 6
#   930  22320 -1.611312623129795e+00 1.3e+00 1.48e-01  1e-01  1e-01 135:57.1
#  calculating generation : 131
# nb de victoires : 0
# nb de morts : 10
#  calculating generation : 132
# nb de victoires : 0
# nb de morts : 7
#  calculating generation : 133
# nb de victoires : 0
# nb de morts : 9
#  calculating generation : 134
# nb de victoires : 0
# nb de morts : 5
#  calculating generation : 135
# nb de victoires : 0
# nb de morts : 5
#  calculating generation : 136
# nb de victoires : 0
# nb de morts : 8
#  calculating generation : 137
# nb de victoires : 0
# nb de morts : 7
#  calculating generation : 138
# nb de victoires : 0
# nb de morts : 4
#   938  22512 -1.180414076163611e+00 1.3e+00 1.48e-01  1e-01  1e-01 138:03.0
#  calculating generation : 139
# nb de victoires : 0
# nb de morts : 4
#  calculating generation : 140
# nb de victoires : 0
# nb de morts : 5
#  calculating generation : 141
# nb de victoires : 0
# nb de morts : 2
#  calculating generation : 142
# nb de victoires : 0
# nb de morts : 5
#  calculating generation : 143
# nb de victoires : 0
# nb de morts : 10
#  calculating generation : 144
# nb de victoires : 0
# nb de morts : 6
#  calculating generation : 145
# nb de victoires : 0
# nb de morts : 8
#  calculating generation : 146
# nb de victoires : 0
# nb de morts : 6
#   946  22704 -1.333152407813457e+00 1.3e+00 1.48e-01  1e-01  1e-01 140:11.8
#  calculating generation : 147
# nb de victoires : 0
# nb de morts : 5
#  calculating generation : 148
# nb de victoires : 0
# nb de morts : 4
#  calculating generation : 149
# nb de victoires : 0
# nb de morts : 11
#  calculating generation : 150
# nb de victoires : 0
# nb de morts : 9
#  calculating generation : 151
# nb de victoires : 0
# nb de morts : 6
#  calculating generation : 152
# nb de victoires : 0
# nb de morts : 10
#  calculating generation : 153
# nb de victoires : 0
# nb de morts : 10
#  calculating generation : 154
# nb de victoires : 0
# nb de morts : 5
#  calculating generation : 155
# nb de victoires : 0
# nb de morts : 5
#   955  22920 -1.700006097730111e+00 1.3e+00 1.48e-01  1e-01  1e-01 142:30.5
#  calculating generation : 156
# nb de victoires : 0
# nb de morts : 8
#  calculating generation : 157
# nb de victoires : 0
# nb de morts : 5
#  calculating generation : 158
# nb de victoires : 0
# nb de morts : 7
#  calculating generation : 159
# nb de victoires : 0
# nb de morts : 9
#  calculating generation : 160
# nb de victoires : 0
# nb de morts : 6
#  calculating generation : 161
# nb de victoires : 0
# nb de morts : 5
#  calculating generation : 162
# nb de victoires : 0
# nb de morts : 1
#  calculating generation : 163
# nb de victoires : 0
# nb de morts : 1
#   963  23112 -2.040977689700267e+00 1.3e+00 1.48e-01  1e-01  1e-01 144:42.3
#  calculating generation : 164
# nb de victoires : 0
# nb de morts : 2
#  calculating generation : 165
# nb de victoires : 0
# nb de morts : 7
#  calculating generation : 166
# nb de victoires : 0
# nb de morts : 0
#  calculating generation : 167
# nb de victoires : 0
# nb de morts : 7
#  calculating generation : 168
# nb de victoires : 0
# nb de morts : 5
#  calculating generation : 169
# nb de victoires : 0
# nb de morts : 6
#   969  23256 -2.603679327904358e+00 1.3e+00 1.47e-01  1e-01  1e-01 154:23.8
#  calculating generation : 170
# nb de victoires : 0
# nb de morts : 2
#  calculating generation : 171
# nb de victoires : 0
# nb de morts : 3
#  calculating generation : 172
# nb de victoires : 0
# nb de morts : 8
#  calculating generation : 173
# nb de victoires : 0
# nb de morts : 6
#  calculating generation : 174
# nb de victoires : 0
# nb de morts : 0
#  calculating generation : 175
# nb de victoires : 0
# nb de morts : 3
#  calculating generation : 176
# nb de victoires : 0
# nb de morts : 7
#  calculating generation : 177
# nb de victoires : 0
# nb de morts : 8
#   977  23448 -2.425055041858052e+00 1.3e+00 1.47e-01  1e-01  1e-01 156:42.1
#  calculating generation : 178
# nb de victoires : 0
# nb de morts : 7
#  calculating generation : 179
# nb de victoires : 0
# nb de morts : 6
#  calculating generation : 180
# nb de victoires : 0
# nb de morts : 5
#  calculating generation : 181
# nb de victoires : 0
# nb de morts : 8
#  calculating generation : 182
# nb de victoires : 0
# nb de morts : 0
#  calculating generation : 183
# nb de victoires : 0
# nb de morts : 5
#  calculating generation : 184
# nb de victoires : 0
# nb de morts : 5
#  calculating generation : 185
# nb de victoires : 0
# nb de morts : 8
#   985  23640 -3.288550675467374e+00 1.3e+00 1.47e-01  1e-01  1e-01 158:56.4
#  calculating generation : 186
# nb de victoires : 0
# nb de morts : 4
#  calculating generation : 187
# nb de victoires : 0
# nb de morts : 9
#  calculating generation : 188
# nb de victoires : 0
# nb de morts : 4
#  calculating generation : 189
# nb de victoires : 0
# nb de morts : 5
#  calculating generation : 190
# nb de victoires : 0
# nb de morts : 3
#  calculating generation : 191
# nb de victoires : 0
# nb de morts : 5
#  calculating generation : 192
# nb de victoires : 0
# nb de morts : 3
#  calculating generation : 193
# nb de victoires : 0
# nb de morts : 5
#   993  23832 -2.449901163860947e+00 1.4e+00 1.47e-01  1e-01  1e-01 161:14.0
#  calculating generation : 194
# nb de victoires : 0
# nb de morts : 9
#  calculating generation : 195
# nb de victoires : 0
# nb de morts : 7
#  calculating generation : 196
# nb de victoires : 0
# nb de morts : 13
#  calculating generation : 197
# nb de victoires : 0
# nb de morts : 8
#  calculating generation : 198
# nb de victoires : 0
# nb de morts : 4
#  calculating generation : 199
# nb de victoires : 0
# nb de morts : 7
#  calculating generation : 200
# nb de victoires : 0
# nb de morts : 4
#  1000  24000 -2.089532835525951e+00 1.4e+00 1.47e-01  1e-01  1e-01 163:08.3
#  calculating generation : 201
# nb de victoires : 0
# nb de morts : 4
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#  calculating generation : 202
# nb de victoires : 0
# nb de morts : 7
#  calculating generation : 203
# nb de victoires : 0
# nb de morts : 7
#  calculating generation : 204
# nb de victoires : 0
# nb de morts : 7
#  calculating generation : 205
# nb de victoires : 0
# nb de morts : 9
#  calculating generation : 206
# nb de victoires : 0
# nb de morts : 5
#  calculating generation : 207
# nb de victoires : 0
# nb de morts : 6
#  calculating generation : 208
# nb de victoires : 0
# nb de morts : 6
#  1008  24192 -3.685840001019482e+00 1.4e+00 1.47e-01  1e-01  1e-01 182:10.2
#  calculating generation : 209
# nb de victoires : 0
# nb de morts : 3
#  calculating generation : 210
# nb de victoires : 0
# nb de morts : 0
#  calculating generation : 211
# nb de victoires : 0
# nb de morts : 5
#  calculating generation : 212
# nb de victoires : 0
# nb de morts : 7
#  1012  24288 -2.125533215133884e+00 1.4e+00 1.47e-01  1e-01  1e-01 189:39.6
#  calculating generation : 213
# nb de victoires : 0
# nb de morts : 12
#  calculating generation : 214
# nb de victoires : 0
# nb de morts : 15
#  calculating generation : 215
# nb de victoires : 0
# nb de morts : 9
#  calculating generation : 216
# nb de victoires : 0
# nb de morts : 6
#  calculating generation : 217
# nb de victoires : 0
# nb de morts : 7
#  calculating generation : 218
# nb de victoires : 0
# nb de morts : 5
#  calculating generation : 219
# nb de victoires : 0
# nb de morts : 12
#  calculating generation : 220
# nb de victoires : 0
# nb de morts : 5
#  calculating generation : 221
# nb de victoires : 0
# nb de morts : 5
#  1021  24504 -2.548797426275370e+00 1.4e+00 1.48e-01  1e-01  1e-01 192:05.4
#  calculating generation : 222
# nb de victoires : 0
# nb de morts : 4
#  calculating generation : 223
# nb de victoires : 0
# nb de morts : 6
#  calculating generation : 224
# nb de victoires : 0
# nb de morts : 7
#  calculating generation : 225
# nb de victoires : 0
# nb de morts : 9
#  calculating generation : 226
# nb de victoires : 0
# nb de morts : 5
#  calculating generation : 227
# nb de victoires : 0
# nb de morts : 5
#  calculating generation : 228
# nb de victoires : 0
# nb de morts : 2
#  calculating generation : 229
# nb de victoires : 0
# nb de morts : 12
#  calculating generation : 230
# nb de victoires : 0
# nb de morts : 15
#  1030  24720 -7.074324768216044e+00 1.4e+00 1.48e-01  1e-01  1e-01 194:35.4
#  calculating generation : 231
# nb de victoires : 0
# nb de morts : 9
#  calculating generation : 232
# nb de victoires : 0
# nb de morts : 7
#  calculating generation : 233
# nb de victoires : 0
# nb de morts : 5
#  calculating generation : 234
# nb de victoires : 0
# nb de morts : 6
#  calculating generation : 235
# nb de victoires : 0
# nb de morts : 8
#  calculating generation : 236
# nb de victoires : 0
# nb de morts : 8
#  calculating generation : 237
# nb de victoires : 0
# nb de morts : 4
#  calculating generation : 238
# nb de victoires : 0
# nb de morts : 6
#  calculating generation : 239
# nb de victoires : 0
# nb de morts : 7
#  1039  24936 -2.837016350853862e+00 1.4e+00 1.48e-01  1e-01  1e-01 197:00.8
#  calculating generation : 240
# nb de victoires : 0
# nb de morts : 7
#  calculating generation : 241
# nb de victoires : 0
# nb de morts : 4
#  calculating generation : 242
# nb de victoires : 0
# nb de morts : 3
#  calculating generation : 243
# nb de victoires : 0
# nb de morts : 5
#  calculating generation : 244
# nb de victoires : 0
# nb de morts : 7
#  calculating generation : 245
# nb de victoires : 0
# nb de morts : 3
#  calculating generation : 246
# nb de victoires : 0
# nb de morts : 9
#  calculating generation : 247
# nb de victoires : 0
# nb de morts : 10
#  calculating generation : 248
# nb de victoires : 0
# nb de morts : 3
#  1048  25152 -1.826453924375036e+00 1.4e+00 1.48e-01  1e-01  1e-01 199:30.2
#  calculating generation : 249
# nb de victoires : 0
# nb de morts : 6
#  calculating generation : 250
# nb de victoires : 0
# nb de morts : 3
#  calculating generation : 251
# nb de victoires : 0
# nb de morts : 11
#  calculating generation : 252
# nb de victoires : 0
# nb de morts : 9
#  calculating generation : 253
# nb de victoires : 0
# nb de morts : 7
#  calculating generation : 254
# nb de victoires : 0
# nb de morts : 6
#  calculating generation : 255
# nb de victoires : 0
# nb de morts : 2
#  calculating generation : 256
# nb de victoires : 0
# nb de morts : 7
#  calculating generation : 257
# nb de victoires : 0
# nb de morts : 1
#  1057  25368 -2.258995218876179e+00 1.4e+00 1.49e-01  1e-01  1e-01 202:01.6
#  calculating generation : 258
# nb de victoires : 0
# nb de morts : 1
#  calculating generation : 259
# nb de victoires : 0
# nb de morts : 5
#  calculating generation : 260
# nb de victoires : 0
# nb de morts : 4
#  calculating generation : 261
# nb de victoires : 0
# nb de morts : 7
#  calculating generation : 262
# nb de victoires : 0
# nb de morts : 3
#  calculating generation : 263
# nb de victoires : 0
# nb de morts : 4
#  calculating generation : 264
# nb de victoires : 0
# nb de morts : 4
#  calculating generation : 265
# nb de victoires : 0
# nb de morts : 6
#  calculating generation : 266
# nb de victoires : 0
# nb de morts : 6
#  1066  25584 -1.691270201429774e+00 1.4e+00 1.49e-01  1e-01  1e-01 204:35.6
#  calculating generation : 267
# nb de victoires : 0
# nb de morts : 3
#  calculating generation : 268
# nb de victoires : 0
# nb de morts : 4
#  calculating generation : 269
# nb de victoires : 0
# nb de morts : 3
#  calculating generation : 270
# nb de victoires : 0
# nb de morts : 7
#  calculating generation : 271
# nb de victoires : 0
# nb de morts : 4
#  calculating generation : 272
# nb de victoires : 0
# nb de morts : 9
#  calculating generation : 273
# nb de victoires : 0
# nb de morts : 11
#  calculating generation : 274
# nb de victoires : 0
# nb de morts : 8
#  calculating generation : 275
# nb de victoires : 0
# nb de morts : 5
#  1075  25800 -1.151665202393881e+00 1.4e+00 1.50e-01  1e-01  2e-01 207:05.1
#  calculating generation : 276
# nb de victoires : 0
# nb de morts : 2
#  calculating generation : 277
# nb de victoires : 0
# nb de morts : 1
#  calculating generation : 278
# nb de victoires : 0
# nb de morts : 4
#  calculating generation : 279
# nb de victoires : 0
# nb de morts : 2
#  calculating generation : 280
# nb de victoires : 0
# nb de morts : 4
#  1080  25920 -1.478456995677728e+00 1.4e+00 1.49e-01  1e-01  2e-01 266:30.5
#  calculating generation : 281
# nb de victoires : 0
# nb de morts : 6
#  calculating generation : 282

# %%
population = pickle.load( open( "./data/gen.pkl", "rb" ) )
population.print_partie(array_trou, array_balle, obstacles, nb_dep)
